# %%
import pandas as pd

df_real = pd.read_csv("adult.csv")

# %%
df_real
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 0       27    Private  177119  Some-college             10
# 1       27    Private  216481     Bachelors             13
# 2       25    Private  256263    Assoc-acdm             12
# 3       46    Private  147640       5th-6th              3
# 4       45    Private  172822          11th              7
# ...    ...        ...     ...           ...            ...
# 32556   43  Local-gov   33331       Masters             14
# 32557   44    Private   98466          10th              6
# 32558   23    Private   45317  Some-college             10
# 32559   45  Local-gov  215862     Doctorate             16
# 32560   25    Private  186925  Some-college             10
#
#            marital-status        occupation   relationship  \
# 0                Divorced      Adm-clerical      Unmarried
# 1           Never-married    Prof-specialty  Not-in-family
# 2      Married-civ-spouse             Sales        Husband
# 3      Married-civ-spouse  Transport-moving        Husband
# 4                Divorced  Transport-moving  Not-in-family
# ...                   ...               ...            ...
# 32556  Married-civ-spouse   Exec-managerial        Husband
# 32557       Never-married   Farming-fishing      Unmarried
# 32558           Separated             Sales      Own-child
# 32559  Married-civ-spouse   Exec-managerial        Husband
# 32560       Never-married     Other-service  Not-in-family
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White  Female             0             0              44
# 1                   White  Female             0             0              40
# 2                   White    Male             0             0              40
# 3      Amer-Indian-Eskimo    Male             0          1902              40
# 4                   White    Male             0          2824              76
# ...                   ...     ...           ...           ...             ...
# 32556               White    Male             0             0              40
# 32557               White    Male             0             0              35
# 32558               White  Female             0             0              40
# 32559               White    Male          7688             0              45
# 32560               White    Male          2597             0              48
#
#       native-country  label
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4      United-States   >50K
# ...              ...    ...
# 32556  United-States   >50K
# 32557  United-States  <=50K
# 32558  United-States  <=50K
# 32559  United-States   >50K
# 32560  United-States  <=50K
#
# [32561 rows x 15 columns]

# %%
# %ls ..\src
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 2421-5EEB
#
#  Directory of D:\Repos2\t-vae-gan\src
#
# 12/07/2025  10:48    <DIR>          .
# 12/07/2025  10:59    <DIR>          ..
# 12/07/2025  09:50                 0 __init__.py
# 12/07/2025  10:48    <DIR>          __pycache__
# 12/07/2025  10:46             6,026 data_handler.py
# 12/07/2025  09:50               740 data_loader.py
# 12/07/2025  10:44               813 decoder_generator.py
# 12/07/2025  10:44             1,332 encoder_critic.py
# 12/07/2025  09:50             1,527 mlp_network.py
# 12/07/2025  10:44             8,725 tvaegan_network.py
# 12/07/2025  10:48             3,765 tvaegan_synthesizer.py
#                8 File(s)         22,928 bytes
#                3 Dir(s)  148,189,745,152 bytes free

# %%
import sys  
sys.path.insert(1, '..\src')

# %%
from src.tvaegan_synthesizer import TVAEGANSynthesizer
# Out:
# [pyKeOps]: Warning, no cuda detected. Switching to cpu only.

# %%
synthesizer = TVAEGANSynthesizer(epochs=1)
synthesizer.fit(df_real)
# Out:
# columns:age, type:int64, added: numerical, unique: 73
# columns:workclass, type:object, added: categorical, unique: 9
# columns:fnlwgt, type:int64, added: numerical, unique: 21648
# columns:education, type:object, added: categorical, unique: 16
# columns:education-num, type:int64, added: numerical, unique: 16
# columns:marital-status, type:object, added: categorical, unique: 7
# columns:occupation, type:object, added: categorical, unique: 15
# columns:relationship, type:object, added: categorical, unique: 6
# columns:race, type:object, added: categorical, unique: 5
# columns:sex, type:object, added: categorical, unique: 2
# columns:capital-gain, type:int64, added: numerical, unique: 119
# columns:capital-loss, type:int64, added: numerical, unique: 92
# columns:hours-per-week, type:int64, added: numerical, unique: 94
# columns:native-country, type:object, added: categorical, unique: 42
# columns:label, type:object, added: categorical, unique: 2
# Empty DataFrame
# Columns: []
# Index: []
# vec_total_length: 366
# in_size: 108
# hidden_layers_sizes: [366, 366]
# latent_dim: 15
# cpu
# encoder total params 180201
# encoder total trainable params 180201
# generat total params 179814
# generat total trainable params 179814
# critic total params 174587
# critic total trainable params 174587
# {'epoch': 1, 'encoder_loss_avg': 5.249146580696106, 'critic_loss_avg': -0.060960778658751005, 'generat_loss_avg': -0.03287167266535107}
# TVAEGANSynthesizer(epochs=1)

# %%
df_synt = synthesizer.predict(len(df_real))

# %%
df_synt
# Out:
#        age workclass  fnlwgt     education  education-num      marital-status  \
# 0       39   Private  428046       HS-grad             10  Married-civ-spouse
# 1       44   Private  315319       HS-grad              9  Married-civ-spouse
# 2       36   Private   12285       HS-grad             10  Married-civ-spouse
# 3       54   Private  376279       HS-grad              9  Married-civ-spouse
# 4       46   Private   52354       HS-grad             10  Married-civ-spouse
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private   12285       HS-grad              9  Married-civ-spouse
# 32557   47   Private  204076       HS-grad             10  Married-civ-spouse
# 32558   48   Private  193886  Some-college             10  Married-civ-spouse
# 32559   49   Private  311473  Some-college              8  Married-civ-spouse
# 32560   49   Private  271026       HS-grad             10  Married-civ-spouse
#
#               occupation   relationship   race   sex  capital-gain  \
# 0      Handlers-cleaners  Not-in-family  White  Male         15410
# 1         Prof-specialty  Not-in-family  White  Male         26198
# 2           Tech-support        Husband  White  Male           811
# 3         Prof-specialty        Husband  White  Male         35707
# 4           Adm-clerical        Husband  White  Male          3158
# ...                  ...            ...    ...   ...           ...
# 32556       Adm-clerical        Husband  White  Male             0
# 32557       Adm-clerical        Husband  White  Male         10849
# 32558     Prof-specialty  Not-in-family  White  Male         24504
# 32559       Adm-clerical        Husband  White  Male         26228
# 32560     Prof-specialty        Husband  White  Male         12584
#
#        capital-loss  hours-per-week native-country  label
# 0              1453              39  United-States  <=50K
# 1              1586              29  United-States  <=50K
# 2              1322              41  United-States  <=50K
# 3              1434              49  United-States  <=50K
# 4               649              39  United-States  <=50K
# ...             ...             ...            ...    ...
# 32556           681              20  United-States  <=50K
# 32557          1393              54  United-States  <=50K
# 32558          1465              45  United-States  <=50K
# 32559          1537              34  United-States  <=50K
# 32560          1155              42  United-States  <=50K
#
# [32561 rows x 15 columns]
